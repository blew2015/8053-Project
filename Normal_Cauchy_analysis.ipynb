# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df_0_1 = pd.read_csv("output_0_1.txt")
#plt.hist(df_0_1)
# prior cauch(0,1)

# %%
#MSE
np.sum(df_0_1**2)/1000
# Out:
# name    0.001004
# dtype: float64

# %%
df_0_100 = pd.read_csv("output_0_100.txt")
#plt.hist(df_0_100)
# prior cauch(0,100)

# %%
#MSE
np.sum(df_0_100**2)/1000
# Out:
# name    0.001005
# dtype: float64

# %%
df_N10_1 = pd.read_csv("output_-10_1.txt")
#plt.hist(df_N10_1)
# prior cauch(-10,1)

# %%
#MSE
np.sum(df_N10_1**2)/1000
# Out:
# name    0.001006
# dtype: float64

# %%
df_N10_100 = pd.read_csv("output_-10_100.txt")
#plt.hist(df_N10_100)
# prior cauch(-10,100)

# %%
#MSE
np.sum(df_N10_100**2)/1000
# Out:
# name    0.001008
# dtype: float64

# %%
df_10_1 = pd.read_csv("output_10_1.txt")
#plt.hist(df_10_1)
# prior cauch(10,1)

# %%
#MSE
np.sum(df_10_1**2)/1000
# Out:
# name    0.001006
# dtype: float64

# %%
df_10_100 = pd.read_csv("output_10_100.txt")
#plt.hist(df_10_100)
# prior cauch(10,100)

# %%
#MSE
np.sum(df_N10_100**2)/1000
# Out:
# name    0.001008
# dtype: float64

# %%
#plt.hist(df_0_1)

# %%
fig, axs = plt.subplots(3, 2, figsize=(10, 12))#, sharey=True)
axs[0,0].tick_params(axis='both', labelsize=15)
axs[0,1].tick_params(axis='both', labelsize=15)
axs[1,0].tick_params(axis='both', labelsize=15)
axs[1,1].tick_params(axis='both', labelsize=15)
axs[2,0].tick_params(axis='both', labelsize=15)
axs[2,1].tick_params(axis='both', labelsize=15)

axs[0, 0].hist(df_0_1)
axs[0, 0].set_xlabel('Sample Mean', fontsize=15)
axs[0, 0].set_ylabel('Frequency', fontsize=15)
#axs[0, 0].set_xl('Cauchy(0,1) as prior', fontsize=15)
axs[0, 0].set_title('Cauchy(0,1) as prior', size=15)
axs[0, 1].hist(df_0_100)
axs[0, 1].set_xlabel('Sample Mean', fontsize=15)
axs[0, 1].set_ylabel('Frequency', fontsize=15)
axs[0, 1].set_title('Cauchy(0,100) as prior', fontsize=15)
axs[1, 0].hist(df_N10_1)
axs[1, 0].set_xlabel('Sample Mean', fontsize=15)
axs[1, 0].set_ylabel('Frequency', fontsize=15)
axs[1, 0].set_title('Cauchy(-10,1) as prior', fontsize=15)
axs[1, 1].hist(df_N10_100)
axs[1, 1].set_xlabel('Sample Mean', fontsize=15)
axs[1, 1].set_ylabel('Frequency', fontsize=15)
axs[1, 1].set_title('Cauchy(-10,100) as prior', fontsize=15)
axs[2, 0].hist(df_10_1)
axs[2, 0].set_xlabel('Sample Mean', fontsize=15)
axs[2, 0].set_ylabel('Frequency', fontsize=15)
axs[2, 0].set_title('Cauchy(10,1) as prior', fontsize=15)
axs[2, 1].hist(df_10_100)
axs[2, 1].set_xlabel('Sample Mean', fontsize=15)
axs[2, 1].set_ylabel('Frequency', fontsize=15)
axs[2, 1].set_title('Cauchy(10,100) as prior', fontsize=15)
plt.tight_layout()
#fig.suptitle('Categorical Plotting')

# %%
axs
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
np.sum(df_0_1**2)/1000
# Out:
# name    0.001004
# dtype: float64

# %%
np.sum(df_0_100**2)/1000
# Out:
# name    0.001005
# dtype: float64

# %%
np.sum(df_N10_1**2)/1000
# Out:
# name    0.001006
# dtype: float64

# %%
np.sum(df_N10_100**2)/1000
# Out:
# name    0.001008
# dtype: float64

# %%
np.sum(df_10_1**2)/1000
# Out:
# name    0.001006
# dtype: float64

# %%
np.sum(df_10_100**2)/1000
# Out:
# name    0.001009
# dtype: float64
